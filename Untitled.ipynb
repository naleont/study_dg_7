# %%
students = int(input('Введите количество учеников: '))

if students <= 2*12:
    print('Мест достаточно.')
else:
    print('Найдите класс побольше.')

# %%
n = int(input('Введите число: '))
if n % 2 == 0:
  print('четное')

# %%
first_name = input('Введите имя: ')
last_name = input('Введите фамилию: ')

print('Здравствуйте, ' + first_name + ' ' + last_name + '!')
# Out:
# Введите имя:  Петя
# Введите фамилию:  Иванов
# Здравствуйте, Петя Иванов!

# %%
'5'
# Out:
# '5'

# %%
5
# Out:
# 5

# %%
n = '35'

print(n[0])
print(n[1])
# Out:
# 3
# 5

# %%
a = 35

print(a[0])
print(a[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 a = 35
# ----> 3 print(a[0])
#       4 print(a[1])
#
# TypeError: 'int' object is not subscriptable

# %%
int('35')
# Out:
# 35

# %%
int('Привет')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int('Привет')
#
# ValueError: invalid literal for int() with base 10: 'Привет'
