# %% [markdown]
# # Циклы. for

# %% [markdown]
# Если `while` выполняет цикл, пока условие выполнения истинно, `for` перебирает данные, пока они не закончатся. Сравните два варианта программы, которая печатает каждую букву слова на новой строке.

# %%
word = 'каскад'
i = 0

while i < len(word):
    print(word[i])
    i += 1
# Out:
# к
# а
# с
# к
# а
# д

# %%
word = 'каскад'

for l in word:
    print (l)
# Out:
# к
# а
# с
# к
# а
# д

# %% [markdown]
# Посмотрим, как этот код работает в [визуальном компиляторе](https://pythontutor.com/visualize.html#mode=edit).

# %% [markdown]
# Элемент, который цикл перебирает, на каждой *итерации* (то есть на каждом повторении) записывается в переменную, которую мы можем использовать внутри цикла.
#
# **Синтаксис.** За `for` следует переменная, в которую записывается то, что перебирает цикл, затем `in` и то, что мы перебираем по элементам. Затем двоеточие и с новой строки с отступом - код цикла.

# %% [markdown]
# ## Функция range()

# %% [markdown]
# `range()` создает набор целых чисел в заданном диапазоне. Два аргумента функции задают начало и конец такого перебора. Обратите внимание: **начало задается включительно, а конец - не включительно.**

# %%
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Начало перебора можно не указывать, тогда перебор начнется с 0.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# При необходимости можно задать третий аргумент: шаг перебора. Если третий аргумент не указан, устанавливается его значение по умолчанию, равное 1.

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(5, 1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
for i in range(1, 5, -1):
    print(i)

# %% [markdown]
# `range()`, конечно, можно использовать и для перечисления индексов.

# %%
word = 'порог'

for i in range(len(word)):
    print(word[i])
# Out:
# п
# о
# р
# о
# г

# %% [markdown]
# `for`, особенно в сочетании с `range()` для многих задач кажется более приятным, поскольку позволяет получить тот же результат меньшим количеством кода. Но и `while` порой оказывается незаменим.

# %% [markdown]
# ## Задание 1
#
# Напечатайте каждое третье число от 7 до 115 включительно. Используйте for и range().

# %% [markdown]
# ## Задание 2
#
# Программа получает слово от пользователя. Длина слова заранее неизвестна. Программа должна напечатать это слово наоборот.

# %% [markdown]
# ## Задание 3
#
# Напечатайте все четные числа от 0 до 100 включительно.

# %% [markdown]
# ## Задание 4
#
# Напечатайте все нечетные числа от 1 до 100 включительно, если они делятся на 3.

# %% [markdown]
# ## Задание 5
#
# Напечатайте каждое пятое число от 127 до -18 включительно в порядке убывания. Используйте for и range().

# %% [markdown]
# ## Задание 6
#
# Напечатайте все отрицательные четные числа от 0 до -100 включительно.

# %% [markdown]
# ## Задание 7.1 *
#
# Напишите программу, которая принимает от пользователя слово, а затем печатает это слово по одной букве на строчке в обратном порядке, используя цикл for. Вам понадобится функция `range()` с тремя аргументами и определение длины строки.
#
# ## Задание 7.2 *
#
# Напишите программу, которая принимает от пользователя слово, а затем собирает это слово в обратном порядке, используя цикл for, и печатает результат одним новым словом.
